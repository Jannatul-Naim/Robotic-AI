# %%
import pyttsx3

engine = pyttsx3.init("sapi5")
voices = engine.getProperty("voices")

print("Voices:")
for i, v in enumerate(voices):
    print(i, v.name)

engine.setProperty("voice", voices[0].id)
engine.setProperty("rate", 170)
engine.setProperty("volume", 1.0)

engine.say("If you hear this, text to speech is working")
engine.runAndWait()
engine.stop()
# Out:
# Voices:
# 0 Microsoft David Desktop - English (United States)
# 1 Microsoft Zira Desktop - English (United States)

# %%
# ===================== DEBUG & SAFETY =====================
DEBUG = True
EMERGENCY_STOP = False

# %%
def log(tag, msg):
    if DEBUG:
        print(f"[{tag}] {msg}")

# %%
def listen(self):
    log("VOICE", "Listening...")
    audio = sd.rec(int(VOICE_TIMEOUT * self.rate),
                   samplerate=self.rate,
                   channels=1,
                   dtype="float32")
    sd.wait()

    audio = np.squeeze(audio)
    result = self.model.transcribe(audio, fp16=torch.cuda.is_available())

    text = result["text"].strip()
    conf = min(0.95, 0.25 + 0.1 * len(text.split()))

    log("VOICE", f"Text='{text}' | Conf={conf}")
    return text, round(conf, 2)
